# %% [markdown]
# ## Pemilihan Fitur

# %%
# # importing the module 
# import cv2 

# # function to display the coordinates of 
# # of the points clicked on the image 
# def click_event(event, x, y, flags, params): 

# 	# checking for left mouse clicks 
# 	if event == cv2.EVENT_LBUTTONDOWN: 

# 		# displaying the coordinates 
# 		# on the Shell 
# 		print(x, ' ', y) 

# 		# displaying the coordinates 
# 		# on the image window 
# 		font = cv2.FONT_HERSHEY_SIMPLEX 
# 		cv2.putText(img, str(x) + ',' +
# 					str(y), (x,y), font, 
# 					1, (255, 0, 0), 2) 
# 		cv2.imshow('image', img) 

# 	# checking for right mouse clicks	 
# 	if event==cv2.EVENT_RBUTTONDOWN: 

# 		# displaying the coordinates 
# 		# on the Shell 
# 		print(x, ' ', y) 

# 		# displaying the coordinates 
# 		# on the image window 
# 		font = cv2.FONT_HERSHEY_SIMPLEX 
# 		b = img[y, x, 0] 
# 		g = img[y, x, 1] 
# 		r = img[y, x, 2] 
# 		cv2.putText(img, str(b) + ',' +
# 					str(g) + ',' + str(r), 
# 					(x,y), font, 1, 
# 					(255, 255, 0), 2) 
# 		cv2.imshow('image', img) 

# # driver function 
# if __name__=="__main__": 

# 	# reading the image 
# 	img = cv2.imread('../video/Frames0.45/frame30.bmp', 1) 

# 	# displaying the image 
# 	cv2.imshow('image', img) 

# 	# setting mouse handler for the image 
# 	# and calling the click_event() function 
# 	cv2.setMouseCallback('image', click_event) 

# 	# wait for a key to be pressed to exit 
# 	cv2.waitKey(0) 

# 	# close the window 
# 	cv2.destroyAllWindows()

# %% [markdown]
# ## Frame 30 dan 31

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((136, 361), (132, 372)),
    ((191, 409), (193, 420)),
    ((137, 508), (133, 508)),
    ((139, 587), (135, 598)),
    ((179, 575), (189, 593)),
    ((185, 627), (189, 632)),
]

# Load the actual images
frame30 = cv2.imread('../../video/Frames0.45/frame30.bmp', cv2.IMREAD_COLOR)
frame31 = cv2.imread('../../video/Frames0.45/frame31.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame30, pos_frame31 in frame_positions:
    cv2.circle(frame30, pos_frame30, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame31, pos_frame31, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame30_rgb = cv2.cvtColor(frame30, cv2.COLOR_BGR2RGB)
frame31_rgb = cv2.cvtColor(frame31, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame30_rgb)
plt.title('Frame 30')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame31_rgb)
plt.title('Frame 31')
plt.axis('off')
plt.savefig('manual0.45_30_31.png')
plt.show()

cv2.imwrite('../video/pemilihan fitur/0.45/frame30_with_circles.jpg', frame30)
# Out:
# False

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame30, pos_frame31 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame31[0] - pos_frame30[0]) ** 2 + (pos_frame31[1] - pos_frame30[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean1 = sum(velocities) / len(velocities)

print("Average Velocity:", mean1, "m/s")
# Out:
# Displacements : 11.704699910719626 pixels
# Velocity: 1.7557049866079437 m/s
#
# Displacements : 11.180339887498949 pixels
# Velocity: 1.6770509831248424 m/s
#
# Displacements : 4.0 pixels
# Velocity: 0.6 m/s
#
# Displacements : 11.704699910719626 pixels
# Velocity: 1.7557049866079437 m/s
#
# Displacements : 20.591260281974 pixels
# Velocity: 3.0886890422961004 m/s
#
# Displacements : 6.4031242374328485 pixels
# Velocity: 0.9604686356149272 m/s
#
# Average Velocity: 1.639603105708626 m/s

# %% [markdown]
# ## Frame 31 dan 32

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((132, 372), (133, 382)),
    ((193, 420), (194, 433)),
    ((133, 508), (135, 517)),
    ((135, 598), (133, 616)),
    ((189, 593), (188, 599)),
    ((189, 632), (188, 642)),
]

# Load the actual images
frame31 = cv2.imread('../video/Frames0.45/frame31.bmp', cv2.IMREAD_COLOR)
frame32 = cv2.imread('../video/Frames0.45/frame32.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame31, pos_frame32 in frame_positions:
    cv2.circle(frame31, pos_frame31, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame32, pos_frame32, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame31_rgb = cv2.cvtColor(frame31, cv2.COLOR_BGR2RGB)
frame32_rgb = cv2.cvtColor(frame32, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame31_rgb)
plt.title('Frame 31')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame32_rgb)
plt.title('Frame 32')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.45/frame31_with_circles.jpg', frame31)

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame31, pos_frame32 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame32[0] - pos_frame31[0]) ** 2 + (pos_frame32[1] - pos_frame31[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean1 = sum(velocities) / len(velocities)

print("Average Velocity:", mean1, "m/s")

# %% [markdown]
# ## Frame 32 dan 33

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((133, 382), (132, 387)),
    ((194, 433), (193, 443)),
    ((135, 517), (133, 526)),
    ((133, 616), (130, 627)),
    ((188, 599), (189, 616)),
    ((188, 642), (188, 651)),
]

# Load the actual images
frame32 = cv2.imread('../video/Frames0.45/frame32.bmp', cv2.IMREAD_COLOR)
frame33 = cv2.imread('../video/Frames0.45/frame33.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame32, pos_frame33 in frame_positions:
    cv2.circle(frame32, pos_frame32, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame33, pos_frame33, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame32_rgb = cv2.cvtColor(frame32, cv2.COLOR_BGR2RGB)
frame33_rgb = cv2.cvtColor(frame33, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame32_rgb)
plt.title('Frame 32')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame33_rgb)
plt.title('Frame 33')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.45/frame32_with_circles.jpg', frame32)

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame32, pos_frame33 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame33[0] - pos_frame32[0]) ** 2 + (pos_frame33[1] - pos_frame32[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean1 = sum(velocities) / len(velocities)

print("Average Velocity:", mean1, "m/s")

# %% [markdown]
# ## Frame 33 dan 34

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((132, 387), (132, 394)),
    ((193, 443), (192, 455)),
    ((133, 526), (133, 535)),
    ((130, 627), (132, 641)),
    ((189, 616), (191, 624)),
    ((188, 651), (189, 665)),
]

# Load the actual images
frame33 = cv2.imread('../video/Frames0.45/frame33.bmp', cv2.IMREAD_COLOR)
frame34 = cv2.imread('../video/Frames0.45/frame34.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame33, pos_frame34 in frame_positions:
    cv2.circle(frame33, pos_frame33, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame34, pos_frame34, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame33_rgb = cv2.cvtColor(frame33, cv2.COLOR_BGR2RGB)
frame34_rgb = cv2.cvtColor(frame34, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame33_rgb)
plt.title('Frame 33')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame34_rgb)
plt.title('Frame 34')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.45/frame33_with_circles.jpg', frame33)

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame33, pos_frame34 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame34[0] - pos_frame33[0]) ** 2 + (pos_frame34[1] - pos_frame33[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean1 = sum(velocities) / len(velocities)

print("Average Velocity:", mean1, "m/s")

# %% [markdown]
# ## Frame 34 dan 35

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((132, 394), (131, 399)),
    ((192, 455), (193, 467)),
    ((133, 535), (133, 544)),
    ((132, 641), (131, 657)),
    ((191, 624), (192, 628)),
    ((189, 665), (192, 676)),
]

# Load the actual images
frame34 = cv2.imread('../video/Frames0.45/frame34.bmp', cv2.IMREAD_COLOR)
frame35 = cv2.imread('../video/Frames0.45/frame35.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame34, pos_frame35 in frame_positions:
    cv2.circle(frame34, pos_frame34, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame35, pos_frame35, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame34_rgb = cv2.cvtColor(frame34, cv2.COLOR_BGR2RGB)
frame35_rgb = cv2.cvtColor(frame35, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame34_rgb)
plt.title('Frame 34')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame35_rgb)
plt.title('Frame 35')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.45/frame34_with_circles.jpg', frame34)

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame34, pos_frame35 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame35[0] - pos_frame34[0]) ** 2 + (pos_frame35[1] - pos_frame34[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean1 = sum(velocities) / len(velocities)

print("Average Velocity:", mean1, "m/s")

# %% [markdown]
# ## Frame 35 dan 36

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((131, 399), (134, 412)),
    ((193, 467), (194, 479)),
    ((133, 544), (132, 563)),
    ((131, 657), (132, 666)),
    ((192, 628), (193, 637)),
    ((192, 676), (193, 698)),
]

# Load the actual images
frame35 = cv2.imread('../video/Frames0.45/frame35.bmp', cv2.IMREAD_COLOR)
frame36 = cv2.imread('../video/Frames0.45/frame36.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame35, pos_frame36 in frame_positions:
    cv2.circle(frame35, pos_frame35, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame36, pos_frame36, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame35_rgb = cv2.cvtColor(frame35, cv2.COLOR_BGR2RGB)
frame36_rgb = cv2.cvtColor(frame36, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame35_rgb)
plt.title('Frame 35')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame36_rgb)
plt.title('Frame 36')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.45/frame35_with_circles.jpg', frame35)

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame35, pos_frame36 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame36[0] - pos_frame35[0]) ** 2 + (pos_frame36[1] - pos_frame35[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean1 = sum(velocities) / len(velocities)

print("Average Velocity:", mean1, "m/s")

# %% [markdown]
# ## Frame 36 dan 37

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((134, 412), (132, 423)),
    ((194, 479), (191, 489)),
    ((132, 563), (132, 572)),
    ((132, 666), (131, 667)),
    ((193, 637), (193, 646)),
    ((193, 698), (193, 705)),
]

# Load the actual images
frame36 = cv2.imread('../video/Frames0.45/frame36.bmp', cv2.IMREAD_COLOR)
frame37 = cv2.imread('../video/Frames0.45/frame37.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame36, pos_frame37 in frame_positions:
    cv2.circle(frame36, pos_frame36, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame37, pos_frame37, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame36_rgb = cv2.cvtColor(frame36, cv2.COLOR_BGR2RGB)
frame37_rgb = cv2.cvtColor(frame37, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame36_rgb)
plt.title('Frame 36')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame37_rgb)
plt.title('Frame 37')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.45/frame36_with_circles.jpg', frame36)

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame36, pos_frame37 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame37[0] - pos_frame36[0]) ** 2 + (pos_frame37[1] - pos_frame36[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean1 = sum(velocities) / len(velocities)

print("Average Velocity:", mean1, "m/s")

# %% [markdown]
# ## Frame 37 dan 38

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((132, 423), (132, 432)),
    ((191, 489), (195, 499)),
    ((132, 572), (131, 589)),
    ((131, 667), (130, 689)),
    ((193, 646), (194, 657)),
    ((193, 705), (192, 725)),
]

# Load the actual images
frame37 = cv2.imread('../video/Frames0.45/frame37.bmp', cv2.IMREAD_COLOR)
frame38 = cv2.imread('../video/Frames0.45/frame38.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame37, pos_frame38 in frame_positions:
    cv2.circle(frame37, pos_frame37, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame38, pos_frame38, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame37_rgb = cv2.cvtColor(frame37, cv2.COLOR_BGR2RGB)
frame38_rgb = cv2.cvtColor(frame38, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame37_rgb)
plt.title('Frame 37')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame38_rgb)
plt.title('Frame 38')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.45/frame37_with_circles.jpg', frame37)

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame37, pos_frame38 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame38[0] - pos_frame37[0]) ** 2 + (pos_frame38[1] - pos_frame37[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean1 = sum(velocities) / len(velocities)

print("Average Velocity:", mean1, "m/s")

# %% [markdown]
# ## Frame 38 dan 39

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((132, 432), (133, 444)),
    ((195, 499), (192, 512)),
    ((131, 589), (130, 604)),
    ((130, 689), (129, 699)),
    ((194, 657), (194, 663)),
    ((192, 725), (190, 740)),
]

# Load the actual images
frame38 = cv2.imread('../video/Frames0.45/frame38.bmp', cv2.IMREAD_COLOR)
frame39 = cv2.imread('../video/Frames0.45/frame39.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame38, pos_frame39 in frame_positions:
    cv2.circle(frame38, pos_frame38, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame39, pos_frame39, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame38_rgb = cv2.cvtColor(frame38, cv2.COLOR_BGR2RGB)
frame39_rgb = cv2.cvtColor(frame39, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame38_rgb)
plt.title('Frame 38')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame39_rgb)
plt.title('Frame 39')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.45/frame38_with_circles.jpg', frame38)

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame38, pos_frame39 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame39[0] - pos_frame38[0]) ** 2 + (pos_frame39[1] - pos_frame38[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean1 = sum(velocities) / len(velocities)

print("Average Velocity:", mean1, "m/s")

# %% [markdown]
# ## Frame 39 dan 40

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((133, 444), (133, 456)),
    ((192, 512), (192, 523)),
    ((130, 604), (129, 608)),
    ((129, 699), (131, 701)),
    ((194, 663), (197, 668)),
    ((190, 740), (192, 750)),
]

# Load the actual images
frame39 = cv2.imread('../video/Frames0.45/frame39.bmp', cv2.IMREAD_COLOR)
frame40 = cv2.imread('../video/Frames0.45/frame40.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame39, pos_frame40 in frame_positions:
    cv2.circle(frame39, pos_frame39, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame40, pos_frame40, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame39_rgb = cv2.cvtColor(frame39, cv2.COLOR_BGR2RGB)
frame40_rgb = cv2.cvtColor(frame40, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame39_rgb)
plt.title('Frame 39')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame40_rgb)
plt.title('Frame 40')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.45/frame39_with_circles.jpg', frame39)

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame39, pos_frame40 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame40[0] - pos_frame39[0]) ** 2 + (pos_frame40[1] - pos_frame39[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean1 = sum(velocities) / len(velocities)

print("Average Velocity:", mean1, "m/s")

# %% [markdown]
# ## Frame 40 dan 41

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((133, 456), (134, 468)),
    ((192, 523), (191, 531)),
    ((129, 608), (131, 610)),
    ((131, 701), (130, 706)),
    ((197, 668), (192, 680)),
    ((192, 750), (192, 759)),
]

# Load the actual images
frame40 = cv2.imread('../video/Frames0.45/frame40.bmp', cv2.IMREAD_COLOR)
frame41 = cv2.imread('../video/Frames0.45/frame41.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame40, pos_frame41 in frame_positions:
    cv2.circle(frame40, pos_frame40, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame41, pos_frame41, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame40_rgb = cv2.cvtColor(frame40, cv2.COLOR_BGR2RGB)
frame41_rgb = cv2.cvtColor(frame41, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame40_rgb)
plt.title('Frame 40')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame41_rgb)
plt.title('Frame 41')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.45/frame40_with_circles.jpg', frame40)

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame40, pos_frame41 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame41[0] - pos_frame40[0]) ** 2 + (pos_frame41[1] - pos_frame40[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean1 = sum(velocities) / len(velocities)

print("Average Velocity:", mean1, "m/s")

# %% [markdown]
# ## Frame 41 dan 42

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((134, 468), (134, 483)),
    ((191, 531), (190, 544)),
    ((131, 610), (132, 617)),
    ((130, 706), (130, 723)),
    ((192, 680), (194, 690)),
    ((192, 759), (192, 770)),
]

# Load the actual images
frame41 = cv2.imread('../video/Frames0.45/frame41.bmp', cv2.IMREAD_COLOR)
frame42 = cv2.imread('../video/Frames0.45/frame42.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame41, pos_frame42 in frame_positions:
    cv2.circle(frame41, pos_frame41, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame42, pos_frame42, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame41_rgb = cv2.cvtColor(frame41, cv2.COLOR_BGR2RGB)
frame42_rgb = cv2.cvtColor(frame42, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame41_rgb)
plt.title('Frame 41')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame42_rgb)
plt.title('Frame 42')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.45/frame41_with_circles.jpg', frame41)

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame41, pos_frame42 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame42[0] - pos_frame41[0]) ** 2 + (pos_frame42[1] - pos_frame41[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean1 = sum(velocities) / len(velocities)

print("Average Velocity:", mean1, "m/s")

# %% [markdown]
# ## Frame 42 dan 43

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((134, 483), (135, 498)),
    ((190, 544), (191, 552)),
    ((132, 617), (130, 627)),
    ((130, 723), (130, 740)),
    ((194, 690), (196, 702)),
    ((190, 775), (192, 780)),
]

# Load the actual images
frame42 = cv2.imread('../video/Frames0.45/frame42.bmp', cv2.IMREAD_COLOR)
frame43 = cv2.imread('../video/Frames0.45/frame43.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame42, pos_frame43 in frame_positions:
    cv2.circle(frame42, pos_frame42, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame43, pos_frame43, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame42_rgb = cv2.cvtColor(frame42, cv2.COLOR_BGR2RGB)
frame43_rgb = cv2.cvtColor(frame43, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame42_rgb)
plt.title('Frame 42')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame43_rgb)
plt.title('Frame 43')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.45/frame42_with_circles.jpg', frame42)

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame41, pos_frame42 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame42[0] - pos_frame41[0]) ** 2 + (pos_frame42[1] - pos_frame41[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean1 = sum(velocities) / len(velocities)

print("Average Velocity:", mean1, "m/s")

# %% [markdown]
# ## Frames 43 dan 44

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((135, 498), (135, 510)),
    ((190, 498), (189, 506)),
    ((187, 530), (188, 542)),
    ((130, 627), (128, 639)),
    ((130, 740), (131, 760)),
    ((195, 702), (194, 715)),
]

# Load the actual images
frame43 = cv2.imread('../video/Frames0.45/frame43.bmp', cv2.IMREAD_COLOR)
frame44 = cv2.imread('../video/Frames0.45/frame44.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame43, pos_frame44 in frame_positions:
    cv2.circle(frame43, pos_frame43, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame44, pos_frame44, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame43_rgb = cv2.cvtColor(frame43, cv2.COLOR_BGR2RGB)
frame44_rgb = cv2.cvtColor(frame44, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame43_rgb)
plt.title('Frame 43')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame44_rgb)
plt.title('Frame 44')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.45/frame43_with_circles.jpg', frame43)

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame43, pos_frame44 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame44[0] - pos_frame43[0]) ** 2 + (pos_frame44[1] - pos_frame43[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean1 = sum(velocities) / len(velocities)

print("Average Velocity:", mean1, "m/s")

# %% [markdown]
# ## Frame 44 dan 45

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((135, 510), (135, 509)),
    ((189, 506), (185, 512)),
    ((188, 542), (188, 551)),
    ((128, 639), (130, 647)),
    ((131, 760), (135, 770)),
    ((194, 715), (195, 718)),
]

# Load the actual images
frame44 = cv2.imread('../video/Frames0.45/frame44.bmp', cv2.IMREAD_COLOR)
frame45 = cv2.imread('../video/Frames0.45/frame45.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame44, pos_frame45 in frame_positions:
    cv2.circle(frame44, pos_frame44, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame45, pos_frame45, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame44_rgb = cv2.cvtColor(frame44, cv2.COLOR_BGR2RGB)
frame45_rgb = cv2.cvtColor(frame45, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame44_rgb)
plt.title('Frame 44')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame45_rgb)
plt.title('Frame 45')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.45/frame44_with_circles.jpg', frame44)

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame44, pos_frame45 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame45[0] - pos_frame44[0]) ** 2 + (pos_frame45[1] - pos_frame44[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean1 = sum(velocities) / len(velocities)

print("Average Velocity:", mean1, "m/s")

# %% [markdown]
# ## Frame 45 dan 46

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((135, 509), (133, 518)),
    ((185, 512), (188, 522)),
    ((188, 551), (192, 569)),
    ((130, 647), (131, 660)),
    ((135, 770), (136, 780)),
    ((195, 718), (193, 735)),
]

# Load the actual images
frame45 = cv2.imread('../video/Frames0.45/frame45.bmp', cv2.IMREAD_COLOR)
frame46 = cv2.imread('../video/Frames0.45/frame46.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame45, pos_frame46 in frame_positions:
    cv2.circle(frame45, pos_frame45, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame46, pos_frame46, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame45_rgb = cv2.cvtColor(frame45, cv2.COLOR_BGR2RGB)
frame46_rgb = cv2.cvtColor(frame46, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame45_rgb)
plt.title('Frame 45')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame46_rgb)
plt.title('Frame 46')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.45/frame45_with_circles.jpg', frame45)

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame45, pos_frame46 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame46[0] - pos_frame45[0]) ** 2 + (pos_frame46[1] - pos_frame45[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean1 = sum(velocities) / len(velocities)

print("Average Velocity:", mean1, "m/s")

# %% [markdown]
# ## Frame 46 dan 47

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((133, 518), (133, 534)),
    ((188, 522), (188, 537)),
    ((192, 569), (192, 583)),
    ((131, 660), (129, 669)),
    ((136, 780), (135, 787)),
    ((193, 735), (190, 740)),
]

# Load the actual images
frame46 = cv2.imread('../video/Frames0.45/frame46.bmp', cv2.IMREAD_COLOR)
frame47 = cv2.imread('../video/Frames0.45/frame47.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame46, pos_frame47 in frame_positions:
    cv2.circle(frame46, pos_frame46, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame47, pos_frame47, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame46_rgb = cv2.cvtColor(frame46, cv2.COLOR_BGR2RGB)
frame47_rgb = cv2.cvtColor(frame47, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame46_rgb)
plt.title('Frame 46')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame47_rgb)
plt.title('Frame 47')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.45/frame46_with_circles.jpg', frame46)

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame46, pos_frame47 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame47[0] - pos_frame46[0]) ** 2 + (pos_frame47[1] - pos_frame46[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean1 = sum(velocities) / len(velocities)

print("Average Velocity:", mean1, "m/s")

# %% [markdown]
# ## Frame 47 dan 48

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((133, 534), (134, 544)),
    ((188, 537), (184, 550)),
    ((192, 583), (191, 593)),
    ((129, 669), (130, 689)),
    ((135, 787), (136, 790)),
    ((190, 740), (190, 755)),
]

# Load the actual images
frame47 = cv2.imread('../video/Frames0.45/frame47.bmp', cv2.IMREAD_COLOR)
frame48 = cv2.imread('../video/Frames0.45/frame48.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame47, pos_frame48 in frame_positions:
    cv2.circle(frame47, pos_frame47, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame48, pos_frame48, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame47_rgb = cv2.cvtColor(frame47, cv2.COLOR_BGR2RGB)
frame48_rgb = cv2.cvtColor(frame48, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame47_rgb)
plt.title('Frame 47')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame48_rgb)
plt.title('Frame 48')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.45/frame47_with_circles.jpg', frame47)

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame47, pos_frame48 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame48[0] - pos_frame47[0]) ** 2 + (pos_frame48[1] - pos_frame47[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean1 = sum(velocities) / len(velocities)

print("Average Velocity:", mean1, "m/s")

# %% [markdown]
# ## Frame 48 dan 49

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((134, 544), (135, 554)),
    ((184, 550), (183, 558)),
    ((191, 593), (187, 610)),
    ((130, 689), (135, 703)),
    ((136, 790), (138, 796)),
    ((190, 755), (192, 760)),
]

# Load the actual images
frame48 = cv2.imread('../video/Frames0.45/frame48.bmp', cv2.IMREAD_COLOR)
frame49 = cv2.imread('../video/Frames0.45/frame49.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame48, pos_frame49 in frame_positions:
    cv2.circle(frame48, pos_frame48, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame49, pos_frame49, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame48_rgb = cv2.cvtColor(frame48, cv2.COLOR_BGR2RGB)
frame49_rgb = cv2.cvtColor(frame49, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame48_rgb)
plt.title('Frame 48')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame49_rgb)
plt.title('Frame 49')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.45/frame48_with_circles.jpg', frame48)

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame48, pos_frame49 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame49[0] - pos_frame48[0]) ** 2 + (pos_frame49[1] - pos_frame48[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean1 = sum(velocities) / len(velocities)

print("Average Velocity:", mean1, "m/s")

# %% [markdown]
# ## Frame 49 dan 50

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((135, 554), (131, 567)),
    ((183, 558), (186, 572)),
    ((187, 610), (192, 618)),
    ((135, 703), (132, 709)),
    ((138, 796), (137, 803)),
    ((192, 760), (192, 775)),
]

# Load the actual images
frame49 = cv2.imread('../video/Frames0.45/frame49.bmp', cv2.IMREAD_COLOR)
frame50 = cv2.imread('../video/Frames0.45/frame50.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame49, pos_frame50 in frame_positions:
    cv2.circle(frame49, pos_frame49, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame50, pos_frame50, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame49_rgb = cv2.cvtColor(frame49, cv2.COLOR_BGR2RGB)
frame50_rgb = cv2.cvtColor(frame50, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame49_rgb)
plt.title('Frame 49')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame50_rgb)
plt.title('Frame 50')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.45/frame49_with_circles.jpg', frame49)

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame49, pos_frame50 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame50[0] - pos_frame49[0]) ** 2 + (pos_frame50[1] - pos_frame49[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean1 = sum(velocities) / len(velocities)

print("Average Velocity:", mean1, "m/s")

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ( (131, 567)),
    ( (186, 572)),
    ((192, 618)),
    ( (132, 709)),
    ((137, 803)),
    ( (192, 775)),
]

# Load the actual images
# frame49 = cv2.imread('../video/Frames0.45/frame49.bmp', cv2.IMREAD_COLOR)
frame50 = cv2.imread('../video/Frames0.45/frame50.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame50 in frame_positions:
    # cv2.circle(frame49, pos_frame49, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame50, pos_frame50, 10, (0, 255, 0), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
# frame49_rgb = cv2.cvtColor(frame49, cv2.COLOR_BGR2RGB)
frame50_rgb = cv2.cvtColor(frame50, cv2.COLOR_BGR2RGB)

# Display the images
# plt.figure( figsize=(5, 10))
# plt.subplot(1, 2, 1)
# plt.imshow(frame49_rgb)
# plt.title('Frame 49')
# plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame50_rgb)
plt.title('Frame 50')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.45/frame50_with_circles.jpg', frame50)
