# %% [markdown]
# ## Pemilihan Fitur

# %% [markdown]
# ## Frame 0 dan 1

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((224, 506), (227, 534)),
    ((109, 497), (102, 525)),
    ((217, 707), (212, 730)),
    ((221, 642), (219, 667)),
    ((86, 720), (82, 746)),
    ((93, 581), (91, 602)),
]

# Load the actual images
frame0 = cv2.imread('../../video/frames0.75/frame0000.bmp', cv2.IMREAD_COLOR)
frame1 = cv2.imread('../../video/frames0.75/frame0001.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame0, pos_frame1 in frame_positions:
    cv2.circle(frame0, pos_frame0, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame1, pos_frame1, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame0_rgb = cv2.cvtColor(frame0, cv2.COLOR_BGR2RGB)
frame1_rgb = cv2.cvtColor(frame1, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame0_rgb)
plt.title('Frame 0  ')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame1_rgb)
plt.title('Frame 1  ')
plt.axis('off')
plt.savefig('manual0.75_0_1.png')
plt.show()
cv2.imwrite('../video/pemilihan fitur/0.75/frame0_with_circles.jpg', frame0)
# Out:
# False

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame0, pos_frame1 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame1[0] - pos_frame0[0]) ** 2 + (pos_frame1[1] - pos_frame0[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean1 = sum(velocities) / len(velocities)

print("Average Velocity:", mean1, "m/s")
# Out:
# Displacements : 28.160255680657446 pixels
# Velocity: 4.224038352098617 m/s
#
# Displacements : 28.861739379323623 pixels
# Velocity: 4.3292609068985435 m/s
#
# Displacements : 23.53720459187964 pixels
# Velocity: 3.530580688781946 m/s
#
# Displacements : 25.079872407968907 pixels
# Velocity: 3.761980861195336 m/s
#
# Displacements : 26.30589287593181 pixels
# Velocity: 3.945883931389772 m/s
#
# Displacements : 21.095023109728988 pixels
# Velocity: 3.164253466459348 m/s
#
# Average Velocity: 3.825999701137261 m/s

# %% [markdown]
# ## Frame 1 dan 2

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((121, 420), (116, 447)),
    ((103, 526), (97, 551)),
    ((227, 533), (228, 560)),
    ((91, 605), (88, 629)),
    ((219, 667), (216, 691)),
    ((214, 730), (212, 758)),
    ((82, 745), (80, 773)),
]

# Load the actual images
frame0 = cv2.imread('../video/frames0.75/frame0001.bmp', cv2.IMREAD_COLOR)
frame1 = cv2.imread('../video/frames0.75/frame0002.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame0, pos_frame1 in frame_positions:
    cv2.circle(frame0, pos_frame0, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame1, pos_frame1, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame0_rgb = cv2.cvtColor(frame0, cv2.COLOR_BGR2RGB)
frame1_rgb = cv2.cvtColor(frame1, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame0_rgb)
plt.title('Frame 1  ')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame1_rgb)
plt.title('Frame 2  ')
plt.axis('off')

plt.show()

cv2.imwrite('../video/pemilihan fitur/0.75/frame1_with_circles.jpg', frame0)
# Out:
# True

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame0, pos_frame1 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame1[0] - pos_frame0[0]) ** 2 + (pos_frame1[1] - pos_frame0[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean2 = sum(velocities) / len(velocities)

print("Velocity:", mean2, "m/s")
# Out:
# Displacements : 27.459060435491963 pixels
# Velocity: 4.118859065323795 m/s
#
# Displacements : 25.709920264364882 pixels
# Velocity: 3.8564880396547325 m/s
#
# Displacements : 27.018512172212592 pixels
# Velocity: 4.052776825831889 m/s
#
# Displacements : 24.186773244895647 pixels
# Velocity: 3.628015986734347 m/s
#
# Displacements : 24.186773244895647 pixels
# Velocity: 3.628015986734347 m/s
#
# Displacements : 28.071337695236398 pixels
# Velocity: 4.21070065428546 m/s
#
# Displacements : 28.071337695236398 pixels
# Velocity: 4.21070065428546 m/s
#
# Velocity: 3.9579367446928617 m/s

# %% [markdown]
# ## Frame 2 dan 3

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement

frame_positions = [
    ((116, 447), (112, 477)),
    ((97, 551), (95, 581)),
    ((228, 560), (229, 586)),
    ((88, 629), (85, 658)),
    ((216, 691), (212, 715)),
    ((212, 758), (213, 782)),
    ((80, 773), (77, 798)),
]

# Load the actual images
frame0 = cv2.imread('../video/frames0.75/frame0002.bmp', cv2.IMREAD_COLOR)
frame1 = cv2.imread('../video/frames0.75/frame0003.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame0, pos_frame1 in frame_positions:
    cv2.circle(frame0, pos_frame0, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame1, pos_frame1, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame0_rgb = cv2.cvtColor(frame0, cv2.COLOR_BGR2RGB)
frame1_rgb = cv2.cvtColor(frame1, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame0_rgb)
plt.title('Frame 2  ')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame1_rgb)
plt.title('Frame 3  ')
plt.axis('off')

plt.show()

cv2.imwrite('../video/pemilihan fitur/0.75/frame2_with_circles.jpg', frame0)
# Out:
# True

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame0, pos_frame1 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame1[0] - pos_frame0[0]) ** 2 + (pos_frame1[1] - pos_frame0[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean3 = sum(velocities) / len(velocities)

print("Velocity:", mean3, "m/s")
# Out:
# Displacements : 30.265491900843113 pixels
# Velocity: 4.539823785126467 m/s
#
# Displacements : 30.066592756745816 pixels
# Velocity: 4.509988913511872 m/s
#
# Displacements : 26.019223662515376 pixels
# Velocity: 3.9028835493773064 m/s
#
# Displacements : 29.154759474226502 pixels
# Velocity: 4.373213921133975 m/s
#
# Displacements : 24.331050121192877 pixels
# Velocity: 3.6496575181789317 m/s
#
# Displacements : 24.020824298928627 pixels
# Velocity: 3.603123644839294 m/s
#
# Displacements : 25.179356624028344 pixels
# Velocity: 3.7769034936042516 m/s
#
# Velocity: 4.050799260824585 m/s

# %% [markdown]
# ## Frame 3 dan 4

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((112, 477), ( 107, 502)),
    ((95, 581), (94, 609)),
    ((229, 586), (227, 617)),
    ((85, 658), (86, 686)),
    ((212, 715), (212, 738)),
    ((213, 782), (205, 799)),
]

# Load the actual images
frame0 = cv2.imread('../video/frames0.75/frame0003.bmp', cv2.IMREAD_COLOR)
frame1 = cv2.imread('../video/frames0.75/frame0004.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame0, pos_frame1 in frame_positions:
    cv2.circle(frame0, pos_frame0, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame1, pos_frame1, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame0_rgb = cv2.cvtColor(frame0, cv2.COLOR_BGR2RGB)
frame1_rgb = cv2.cvtColor(frame1, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame0_rgb)
plt.title('Frame 3  ')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame1_rgb)
plt.title('Frame 4  ')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.75/frame3_with_circles.jpg', frame0)
# Out:
# True

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame0, pos_frame1 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame1[0] - pos_frame0[0]) ** 2 + (pos_frame1[1] - pos_frame0[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean4 = sum(velocities) / len(velocities)

print("Velocity:", mean4, "m/s")
# Out:
# Displacements : 25.495097567963924 pixels
# Velocity: 3.824264635194589 m/s
#
# Displacements : 28.0178514522438 pixels
# Velocity: 4.20267771783657 m/s
#
# Displacements : 31.064449134018133 pixels
# Velocity: 4.65966737010272 m/s
#
# Displacements : 28.0178514522438 pixels
# Velocity: 4.20267771783657 m/s
#
# Displacements : 23.0 pixels
# Velocity: 3.4499999999999997 m/s
#
# Displacements : 18.788294228055936 pixels
# Velocity: 2.81824413420839 m/s
#
# Velocity: 3.8595885958631393 m/s

# %% [markdown]
# ## Frame 4 dan 5

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((107, 502), ( 104, 531)),
    ((94, 609), (89, 635)),
    ((227, 617), (226, 643)),
    ((86, 686), (81, 714)),
    ((212, 738), (211, 764)),
]

# Load the actual images
frame0 = cv2.imread('../video/frames0.75/frame0004.bmp', cv2.IMREAD_COLOR)
frame1 = cv2.imread('../video/frames0.75/frame0005.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame0, pos_frame1 in frame_positions:
    cv2.circle(frame0, pos_frame0, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame1, pos_frame1, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame0_rgb = cv2.cvtColor(frame0, cv2.COLOR_BGR2RGB)
frame1_rgb = cv2.cvtColor(frame1, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame0_rgb)
plt.title('Frame 4  ')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame1_rgb)
plt.title('Frame 5  ')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.75/frame4_with_circles.jpg', frame0)
# Out:
# True

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame0, pos_frame1 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame1[0] - pos_frame0[0]) ** 2 + (pos_frame1[1] - pos_frame0[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean5 = sum(velocities) / len(velocities)

print("Velocity:", mean5, "m/s")
# Out:
# Displacements : 29.154759474226502 pixels
# Velocity: 4.373213921133975 m/s
#
# Displacements : 26.476404589747453 pixels
# Velocity: 3.971460688462118 m/s
#
# Displacements : 26.019223662515376 pixels
# Velocity: 3.9028835493773064 m/s
#
# Displacements : 28.442925306655784 pixels
# Velocity: 4.266438795998368 m/s
#
# Displacements : 26.019223662515376 pixels
# Velocity: 3.9028835493773064 m/s
#
# Velocity: 4.083376100869815 m/s

# %% [markdown]
# ## Frame 5 dan 6

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((128, 386), ( 127, 413)),
    ((104, 530), (104, 557)),
    ((90, 633), (86, 660)),
    ((227, 641), (222, 671)),
    ((218, 682), (218, 706)),
    ((81, 713), (80, 741)),
    ((212, 764), (208, 788)),
]

# Load the actual images
frame0 = cv2.imread('../video/frames0.75/frame0005.bmp', cv2.IMREAD_COLOR)
frame1 = cv2.imread('../video/frames0.75/frame0006.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame0, pos_frame1 in frame_positions:
    cv2.circle(frame0, pos_frame0, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame1, pos_frame1, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame0_rgb = cv2.cvtColor(frame0, cv2.COLOR_BGR2RGB)
frame1_rgb = cv2.cvtColor(frame1, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame0_rgb)
plt.title('Frame 5  ')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame1_rgb)
plt.title('Frame 6  ')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.75/frame5_with_circles.jpg', frame0)
# Out:
# True

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame0, pos_frame1 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame1[0] - pos_frame0[0]) ** 2 + (pos_frame1[1] - pos_frame0[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean6 = sum(velocities) / len(velocities)

print("Velocity:", mean6, "m/s")
# Out:
# Displacements : 27.018512172212592 pixels
# Velocity: 4.052776825831889 m/s
#
# Displacements : 27.0 pixels
# Velocity: 4.05 m/s
#
# Displacements : 27.294688127912362 pixels
# Velocity: 4.094203219186855 m/s
#
# Displacements : 30.4138126514911 pixels
# Velocity: 4.562071897723665 m/s
#
# Displacements : 24.0 pixels
# Velocity: 3.6 m/s
#
# Displacements : 28.0178514522438 pixels
# Velocity: 4.20267771783657 m/s
#
# Displacements : 24.331050121192877 pixels
# Velocity: 3.6496575181789317 m/s
#
# Velocity: 4.030198168393988 m/s

# %% [markdown]
# ## Frame 6 dan 7

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((127, 413), (127, 432)),
    ((104, 557), (101, 584)),
    ((86, 660), (84, 687)),
    ((222, 671), (214, 699)),
    ((218, 706), (213, 729)),
    ((80, 741), (79, 768)),
]

# Load the actual images
frame0 = cv2.imread('../video/frames0.75/frame0006.bmp', cv2.IMREAD_COLOR)
frame1 = cv2.imread('../video/frames0.75/frame0007.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame0, pos_frame1 in frame_positions:
    cv2.circle(frame0, pos_frame0, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame1, pos_frame1, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame0_rgb = cv2.cvtColor(frame0, cv2.COLOR_BGR2RGB)
frame1_rgb = cv2.cvtColor(frame1, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame0_rgb)
plt.title('Frame 6  ')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame1_rgb)
plt.title('Frame 7  ')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.75/frame6_with_circles.jpg', frame0)
# Out:
# True

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame0, pos_frame1 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame1[0] - pos_frame0[0]) ** 2 + (pos_frame1[1] - pos_frame0[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean7 = sum(velocities) / len(velocities)

print("Velocity:", mean7, "m/s")
# Out:
# Displacements : 19.0 pixels
# Velocity: 2.85 m/s
#
# Displacements : 27.16615541441225 pixels
# Velocity: 4.074923312161837 m/s
#
# Displacements : 27.073972741361768 pixels
# Velocity: 4.061095911204265 m/s
#
# Displacements : 29.120439557122072 pixels
# Velocity: 4.368065933568311 m/s
#
# Displacements : 23.53720459187964 pixels
# Velocity: 3.530580688781946 m/s
#
# Displacements : 27.018512172212592 pixels
# Velocity: 4.052776825831889 m/s
#
# Velocity: 3.822907111924708 m/s

# %% [markdown]
# ## Frame 7 dan 8

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((127, 432), (121,442)),
    ((101, 584), (100,608)),
    ((84, 687), (81,712)),
    ((214, 699), (211,724)),
    ((213, 729), (218,751)),
    ((79, 768), (77,795)),
]
# Load the actual images
frame0 = cv2.imread('../video/frames0.75/frame0007.bmp', cv2.IMREAD_COLOR)
frame1 = cv2.imread('../video/frames0.75/frame0008.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame0, pos_frame1 in frame_positions:
    cv2.circle(frame0, pos_frame0, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame1, pos_frame1, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame0_rgb = cv2.cvtColor(frame0, cv2.COLOR_BGR2RGB)
frame1_rgb = cv2.cvtColor(frame1, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame0_rgb)
plt.title('Frame 7  ')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame1_rgb)
plt.title('Frame 8  ')
plt.axis('off')

plt.show()

cv2.imwrite('../video/pemilihan fitur/0.75/frame7_with_circles.jpg', frame0)
# Out:
# True

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame0, pos_frame1 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame1[0] - pos_frame0[0]) ** 2 + (pos_frame1[1] - pos_frame0[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean8 = sum(velocities) / len(velocities)

print("Velocity:", mean8, "m/s")
# Out:
# Displacements : 11.661903789690601 pixels
# Velocity: 1.7492855684535902 m/s
#
# Displacements : 24.020824298928627 pixels
# Velocity: 3.603123644839294 m/s
#
# Displacements : 25.179356624028344 pixels
# Velocity: 3.7769034936042516 m/s
#
# Displacements : 25.179356624028344 pixels
# Velocity: 3.7769034936042516 m/s
#
# Displacements : 22.561028345356956 pixels
# Velocity: 3.3841542518035435 m/s
#
# Displacements : 27.073972741361768 pixels
# Velocity: 4.061095911204265 m/s
#
# Velocity: 3.391911060584866 m/s

# %% [markdown]
# ## Frame 8 dan 9

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((121,442), (119,471)),
    ((113,489), (109,520)),
    ((225,575), (228,606)),
    ((81,712), (82,741)),
    ((211,724), (210,743)),
    ((218,751), (221,773)),
]
# Load the actual images
frame0 = cv2.imread('../video/frames0.75/frame0008.bmp', cv2.IMREAD_COLOR)
frame1 = cv2.imread('../video/frames0.75/frame0009.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame0, pos_frame1 in frame_positions:
    cv2.circle(frame0, pos_frame0, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame1, pos_frame1, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame0_rgb = cv2.cvtColor(frame0, cv2.COLOR_BGR2RGB)
frame1_rgb = cv2.cvtColor(frame1, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure( figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame0_rgb)
plt.title('Frame 8  ')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame1_rgb)
plt.title('Frame 9  ')
plt.axis('off')

plt.show()

cv2.imwrite('../video/pemilihan fitur/0.75/frame8_with_circles.jpg', frame0)
# Out:
# True

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame0, pos_frame1 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame1[0] - pos_frame0[0]) ** 2 + (pos_frame1[1] - pos_frame0[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean9 = sum(velocities) / len(velocities)

print("Velocity:", mean9, "m/s")
# Out:
# Displacements : 29.068883707497267 pixels
# Velocity: 4.3603325561245905 m/s
#
# Displacements : 31.25699921617557 pixels
# Velocity: 4.688549882426336 m/s
#
# Displacements : 31.144823004794873 pixels
# Velocity: 4.671723450719231 m/s
#
# Displacements : 29.017236257093817 pixels
# Velocity: 4.3525854385640725 m/s
#
# Displacements : 19.026297590440446 pixels
# Velocity: 2.853944638566067 m/s
#
# Displacements : 22.20360331117452 pixels
# Velocity: 3.3305404966761776 m/s
#
# Velocity: 4.042946077179413 m/s

# %% [markdown]
# ## Frame 9 dan 10

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((119,471), (119,498)),
    ((109,520), (106,543)),
    ((227,514), (229,545)),
    ((228,606), (229,634)),
    ((82,741), (82,763)),
    ((210,743), (215,764)),
]

# Load the actual images
frame0 = cv2.imread('../video/frames0.75/frame0009.bmp', cv2.IMREAD_COLOR)
frame1 = cv2.imread('../video/frames0.75/frame0010.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame0, pos_frame1 in frame_positions:
    cv2.circle(frame0, pos_frame0, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame1, pos_frame1, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame0_rgb = cv2.cvtColor(frame0, cv2.COLOR_BGR2RGB)
frame1_rgb = cv2.cvtColor(frame1, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure(figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame0_rgb)
plt.title('Frame 9  ')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame1_rgb)
plt.title('Frame 10  ')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.75/frame9_with_circles.jpg', frame0)
# Out:
# True

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame0, pos_frame1 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame1[0] - pos_frame0[0]) ** 2 + (pos_frame1[1] - pos_frame0[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean10 = sum(velocities) / len(velocities)

print("Velocity:", mean10, "m/s")
# Out:
# Displacements : 27.0 pixels
# Velocity: 4.05 m/s
#
# Displacements : 23.194827009486403 pixels
# Velocity: 3.4792240514229604 m/s
#
# Displacements : 31.064449134018133 pixels
# Velocity: 4.65966737010272 m/s
#
# Displacements : 28.0178514522438 pixels
# Velocity: 4.20267771783657 m/s
#
# Displacements : 22.0 pixels
# Velocity: 3.3 m/s
#
# Displacements : 21.587033144922902 pixels
# Velocity: 3.2380549717384355 m/s
#
# Velocity: 3.821604018516781 m/s

# %% [markdown]
# ## Frame 10 dan 11

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((119, 498), (122, 526)),
    ((106, 543), (109, 564)),
    ((229, 545), (228, 576)),
    ((229, 634), (227, 665)),
    ((82, 763),  (87, 783)),
    ((215, 764), (215, 780)),
]

# Load the actual images
frame10 = cv2.imread('../Video/Frames0.75/frame0010.bmp', cv2.IMREAD_COLOR)
frame11 = cv2.imread('../Video/Frames0.75/frame0011.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame10, pos_frame11 in frame_positions:
    cv2.circle(frame10, pos_frame10, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame11, pos_frame11, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame10_rgb = cv2.cvtColor(frame10, cv2.COLOR_BGR2RGB)
frame11_rgb = cv2.cvtColor(frame11, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure(figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame10_rgb)
plt.title('Frame 10')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame11_rgb)
plt.title('Frame 11')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.75/frame10_with_circles.jpg', frame10)
# Out:
# True

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame10, pos_frame11 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame11[0] - pos_frame10[0]) ** 2 + (pos_frame11[1] - pos_frame10[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean10 = sum(velocities) / len(velocities)

print("Velocity:", mean10, "m/s")
# Out:
# Displacements : 28.160255680657446 pixels
# Velocity: 4.224038352098617 m/s
#
# Displacements : 21.213203435596427 pixels
# Velocity: 3.1819805153394642 m/s
#
# Displacements : 31.016124838541646 pixels
# Velocity: 4.6524187257812475 m/s
#
# Displacements : 31.064449134018133 pixels
# Velocity: 4.65966737010272 m/s
#
# Displacements : 20.615528128088304 pixels
# Velocity: 3.0923292192132457 m/s
#
# Displacements : 16.0 pixels
# Velocity: 2.4 m/s
#
# Velocity: 3.7017390304225484 m/s

# %% [markdown]
# ## Frame 11 dan 12

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((130, 396), (124, 419)),
    ((130, 420), (127, 449)),
    ((122, 526), (116, 549)),
    ((109, 564), (106, 589)),
    ((228, 576), (229, 606)),
    ((227, 665), (225, 694)),
]

# Load the actual images
frame11 = cv2.imread('../Video/Frames0.75/frame0011.bmp', cv2.IMREAD_COLOR)
frame12 = cv2.imread('../Video/Frames0.75/frame0012.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame11, pos_frame12 in frame_positions:
    cv2.circle(frame11, pos_frame11, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame12, pos_frame12, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame11_rgb = cv2.cvtColor(frame11, cv2.COLOR_BGR2RGB)
frame12_rgb = cv2.cvtColor(frame12, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure(figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame11_rgb)
plt.title('Frame 11')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame12_rgb)
plt.title('Frame 12')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.75/frame11_with_circles.jpg', frame11)
# Out:
# True

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame11, pos_frame12 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame12[0] - pos_frame11[0]) ** 2 + (pos_frame12[1] - pos_frame11[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean10 = sum(velocities) / len(velocities)

print("Velocity:", mean10, "m/s")
# Out:
# Displacements : 23.769728648009426 pixels
# Velocity: 3.565459297201414 m/s
#
# Displacements : 29.154759474226502 pixels
# Velocity: 4.373213921133975 m/s
#
# Displacements : 23.769728648009426 pixels
# Velocity: 3.565459297201414 m/s
#
# Displacements : 25.179356624028344 pixels
# Velocity: 3.7769034936042516 m/s
#
# Displacements : 30.01666203960727 pixels
# Velocity: 4.5024993059410905 m/s
#
# Displacements : 29.068883707497267 pixels
# Velocity: 4.3603325561245905 m/s
#
# Velocity: 4.023977978534456 m/s

# %% [markdown]
# ## Frame 12 dan 13

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((124, 419), (121, 440)),
    ((127, 449), (123, 473)),
    ((116, 549), (112, 575)),
    ((106, 589), (106, 612)),
    ((229, 606), (226, 634)),
    ((225, 694), (225, 723)),
]

# Load the actual images
frame12 = cv2.imread('../Video/Frames0.75/frame0012.bmp', cv2.IMREAD_COLOR)
frame13 = cv2.imread('../Video/Frames0.75/frame0013.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame12, pos_frame13 in frame_positions:
    cv2.circle(frame12, pos_frame12, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame13, pos_frame13, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame12_rgb = cv2.cvtColor(frame12, cv2.COLOR_BGR2RGB)
frame13_rgb = cv2.cvtColor(frame13, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure(figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame12_rgb)
plt.title('Frame 12')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame13_rgb)
plt.title('Frame 13')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.75/frame12_with_circles.jpg', frame12)
# Out:
# True

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame12, pos_frame13 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame13[0] - pos_frame12[0]) ** 2 + (pos_frame13[1] - pos_frame12[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean10 = sum(velocities) / len(velocities)

print("Velocity:", mean10, "m/s")
# Out:
# Displacements : 21.213203435596427 pixels
# Velocity: 3.1819805153394642 m/s
#
# Displacements : 24.331050121192877 pixels
# Velocity: 3.6496575181789317 m/s
#
# Displacements : 26.30589287593181 pixels
# Velocity: 3.945883931389772 m/s
#
# Displacements : 23.0 pixels
# Velocity: 3.4499999999999997 m/s
#
# Displacements : 28.160255680657446 pixels
# Velocity: 4.224038352098617 m/s
#
# Displacements : 29.0 pixels
# Velocity: 4.35 m/s
#
# Velocity: 3.8002600528344637 m/s

# %% [markdown]
# ## Frame 13 dan 14

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((121, 440), (117, 465)),
    ((123, 473), (117, 501)),
    ((112, 575), (108, 603)),
    ((106, 612), (108, 636)),
    ((226, 634), (227, 664)),
    ((225, 723), (223, 750)),
]

# Load the actual images
frame13 = cv2.imread('../Video/Frames0.75/frame0013.bmp', cv2.IMREAD_COLOR)
frame14 = cv2.imread('../Video/Frames0.75/frame0014.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame13, pos_frame14 in frame_positions:
    cv2.circle(frame13, pos_frame13, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame14, pos_frame14, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame13_rgb = cv2.cvtColor(frame13, cv2.COLOR_BGR2RGB)
frame14_rgb = cv2.cvtColor(frame14, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure(figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame13_rgb)
plt.title('Frame 13')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame14_rgb)
plt.title('Frame 14')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.75/frame13_with_circles.jpg', frame13)
# Out:
# True

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame13, pos_frame14 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame14[0] - pos_frame13[0]) ** 2 + (pos_frame14[1] - pos_frame13[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean10 = sum(velocities) / len(velocities)

print("Velocity:", mean10, "m/s")
# Out:
# Displacements : 25.317977802344327 pixels
# Velocity: 3.797696670351649 m/s
#
# Displacements : 28.635642126552707 pixels
# Velocity: 4.295346318982906 m/s
#
# Displacements : 28.284271247461902 pixels
# Velocity: 4.242640687119286 m/s
#
# Displacements : 24.08318915758459 pixels
# Velocity: 3.6124783736376886 m/s
#
# Displacements : 30.01666203960727 pixels
# Velocity: 4.5024993059410905 m/s
#
# Displacements : 27.073972741361768 pixels
# Velocity: 4.061095911204265 m/s
#
# Velocity: 4.085292877872814 m/s

# %% [markdown]
# ## Frame 14 dan 15

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((117, 465), (114, 496)),
    ((117, 501), (113, 533)),
    ((108, 603), (105, 632)),
    ((108, 636), (108, 661)),
    ((227, 664), (224, 691)),
    ((223, 750), (221, 780)),
]

# Load the actual images
frame14 = cv2.imread('../Video/Frames0.75/frame0014.bmp', cv2.IMREAD_COLOR)
frame15 = cv2.imread('../Video/Frames0.75/frame0015.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame14, pos_frame15 in frame_positions:
    cv2.circle(frame14, pos_frame14, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame15, pos_frame15, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame14_rgb = cv2.cvtColor(frame14, cv2.COLOR_BGR2RGB)
frame15_rgb = cv2.cvtColor(frame15, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure(figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame14_rgb)
plt.title('Frame 14')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame15_rgb)
plt.title('Frame 15')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.75/frame14_with_circles.jpg', frame14)
# Out:
# True

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame14, pos_frame15 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame15[0] - pos_frame14[0]) ** 2 + (pos_frame15[1] - pos_frame14[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean10 = sum(velocities) / len(velocities)

print("Velocity:", mean10, "m/s")
# Out:
# Displacements : 31.144823004794873 pixels
# Velocity: 4.671723450719231 m/s
#
# Displacements : 32.2490309931942 pixels
# Velocity: 4.8373546489791295 m/s
#
# Displacements : 29.154759474226502 pixels
# Velocity: 4.373213921133975 m/s
#
# Displacements : 25.0 pixels
# Velocity: 3.75 m/s
#
# Displacements : 27.16615541441225 pixels
# Velocity: 4.074923312161837 m/s
#
# Displacements : 30.066592756745816 pixels
# Velocity: 4.509988913511872 m/s
#
# Velocity: 4.36953404108434 m/s

# %% [markdown]
# ## Frame 15 dan 16

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((114, 496), (109, 524)),
    ((113, 533), (108, 563)),
    ((105, 632), (104, 656)),
    ((108, 661), (109, 685)),
    ((224, 691), (219, 720)),
    ((221, 780), (210, 800)),
]

# Load the actual images
frame15 = cv2.imread('../Video/Frames0.75/frame0015.bmp', cv2.IMREAD_COLOR)
frame16 = cv2.imread('../Video/Frames0.75/frame0016.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame15, pos_frame16 in frame_positions:
    cv2.circle(frame15, pos_frame15, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame16, pos_frame16, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame15_rgb = cv2.cvtColor(frame15, cv2.COLOR_BGR2RGB)
frame16_rgb = cv2.cvtColor(frame16, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure(figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame15_rgb)
plt.title('Frame 15')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame16_rgb)
plt.title('Frame 16')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.75/frame15_with_circles.jpg', frame15)
# Out:
# True

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame15, pos_frame16 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame16[0] - pos_frame15[0]) ** 2 + (pos_frame16[1] - pos_frame15[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean10 = sum(velocities) / len(velocities)

print("Velocity:", mean10, "m/s")
# Out:
# Displacements : 28.442925306655784 pixels
# Velocity: 4.266438795998368 m/s
#
# Displacements : 30.4138126514911 pixels
# Velocity: 4.562071897723665 m/s
#
# Displacements : 24.020824298928627 pixels
# Velocity: 3.603123644839294 m/s
#
# Displacements : 24.020824298928627 pixels
# Velocity: 3.603123644839294 m/s
#
# Displacements : 29.427877939124322 pixels
# Velocity: 4.414181690868649 m/s
#
# Displacements : 22.825424421026653 pixels
# Velocity: 3.4238136631539984 m/s
#
# Velocity: 3.9787922229038784 m/s

# %% [markdown]
# ## Frame 16 dan 17

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((109, 524), (105, 550)),
    ((108, 563), (107, 589)),
    ((104, 656), (101, 684)),
    ((109, 685), (109, 710)),
    ((219, 720), (213, 750)),
    ((215, 523), (215, 547)),
]

# Load the actual images
frame16 = cv2.imread('../Video/Frames0.75/frame0016.bmp', cv2.IMREAD_COLOR)
frame17 = cv2.imread('../Video/Frames0.75/frame0017.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame16, pos_frame17 in frame_positions:
    cv2.circle(frame16, pos_frame16, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame17, pos_frame17, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame16_rgb = cv2.cvtColor(frame16, cv2.COLOR_BGR2RGB)
frame17_rgb = cv2.cvtColor(frame17, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure(figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame16_rgb)
plt.title('Frame 16')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame17_rgb)
plt.title('Frame 17')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.75/frame16_with_circles.jpg', frame16)
# Out:
# True

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame16, pos_frame17 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame17[0] - pos_frame16[0]) ** 2 + (pos_frame17[1] - pos_frame16[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean10 = sum(velocities) / len(velocities)

print("Velocity:", mean10, "m/s")
# Out:
# Displacements : 26.30589287593181 pixels
# Velocity: 3.945883931389772 m/s
#
# Displacements : 26.019223662515376 pixels
# Velocity: 3.9028835493773064 m/s
#
# Displacements : 28.160255680657446 pixels
# Velocity: 4.224038352098617 m/s
#
# Displacements : 25.0 pixels
# Velocity: 3.75 m/s
#
# Displacements : 30.59411708155671 pixels
# Velocity: 4.589117562233507 m/s
#
# Displacements : 24.0 pixels
# Velocity: 3.6 m/s
#
# Velocity: 4.001987232516534 m/s

# %% [markdown]
# ## Frame 17 dan 18

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((105, 550), (103, 581)),
    ((107, 589), (103, 622)),
    ((101, 684), (100, 702)),
    ((109, 710), (111, 723)),
    ((213, 750), (213, 776)),
    ((215, 547), (216, 572)),
]

# Load the actual images
frame17 = cv2.imread('../Video/Frames0.75/frame0017.bmp', cv2.IMREAD_COLOR)
frame18 = cv2.imread('../Video/Frames0.75/frame0018.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame17, pos_frame18 in frame_positions:
    cv2.circle(frame17, pos_frame17, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame18, pos_frame18, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame17_rgb = cv2.cvtColor(frame17, cv2.COLOR_BGR2RGB)
frame18_rgb = cv2.cvtColor(frame18, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure(figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame17_rgb)
plt.title('Frame 17')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame18_rgb)
plt.title('Frame 18')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.75/frame17_with_circles.jpg', frame17)
# Out:
# True

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame17, pos_frame18 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame18[0] - pos_frame17[0]) ** 2 + (pos_frame18[1] - pos_frame17[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean10 = sum(velocities) / len(velocities)

print("Velocity:", mean10, "m/s")
# Out:
# Displacements : 31.064449134018133 pixels
# Velocity: 4.65966737010272 m/s
#
# Displacements : 33.24154027718932 pixels
# Velocity: 4.986231041578399 m/s
#
# Displacements : 18.027756377319946 pixels
# Velocity: 2.704163456597992 m/s
#
# Displacements : 13.152946437965905 pixels
# Velocity: 1.972941965694886 m/s
#
# Displacements : 26.0 pixels
# Velocity: 3.9 m/s
#
# Displacements : 25.019992006393608 pixels
# Velocity: 3.752998800959041 m/s
#
# Velocity: 3.662667105822173 m/s

# %% [markdown]
# ## Frame 18 dan 19

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((103, 581), (103, 608)),
    ((103, 622), (101, 660)),
    ((100, 702), (106, 725)),
    ((111, 723), (114, 745)),
    ((213, 776), (212, 807)),
    ((216, 572), (215, 590)),
]

# Load the actual images
frame18 = cv2.imread('../Video/Frames0.75/frame0018.bmp', cv2.IMREAD_COLOR)
frame19 = cv2.imread('../Video/Frames0.75/frame0019.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame18, pos_frame19 in frame_positions:
    cv2.circle(frame18, pos_frame18, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame19, pos_frame19, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame18_rgb = cv2.cvtColor(frame18, cv2.COLOR_BGR2RGB)
frame19_rgb = cv2.cvtColor(frame19, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure(figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame18_rgb)
plt.title('Frame 18')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame19_rgb)
plt.title('Frame 19')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.75/frame18_with_circles.jpg', frame18)
# Out:
# True

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame18, pos_frame19 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame19[0] - pos_frame18[0]) ** 2 + (pos_frame19[1] - pos_frame18[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean10 = sum(velocities) / len(velocities)

print("Velocity:", mean10, "m/s")
# Out:
# Displacements : 27.0 pixels
# Velocity: 4.05 m/s
#
# Displacements : 38.05259518088089 pixels
# Velocity: 5.707889277132134 m/s
#
# Displacements : 23.769728648009426 pixels
# Velocity: 3.565459297201414 m/s
#
# Displacements : 22.20360331117452 pixels
# Velocity: 3.3305404966761776 m/s
#
# Displacements : 31.016124838541646 pixels
# Velocity: 4.6524187257812475 m/s
#
# Displacements : 18.027756377319946 pixels
# Velocity: 2.704163456597992 m/s
#
# Velocity: 4.0017452088981615 m/s

# %% [markdown]
# ## Frame 19 dan 20

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((103, 608), (101, 632)),
    ((101, 660), (103, 690)),
    ((106, 725), (103, 750)),
    ((114, 745), (110, 765)),
    ((200, 658), (200, 688)),
    ((215, 590), (210, 620)),
]

# Load the actual images
frame19 = cv2.imread('../Video/Frames0.75/frame0019.bmp', cv2.IMREAD_COLOR)
frame20 = cv2.imread('../Video/Frames0.75/frame0020.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame19, pos_frame20 in frame_positions:
    cv2.circle(frame19, pos_frame19, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame20, pos_frame20, 10, (0, 0, 255), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame19_rgb = cv2.cvtColor(frame19, cv2.COLOR_BGR2RGB)
frame20_rgb = cv2.cvtColor(frame20, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure(figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame19_rgb)
plt.title('Frame 19')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame20_rgb)
plt.title('Frame 20')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.75/frame19_with_circles.jpg', frame19)
# Out:
# True

# %%
# Calculate displacement and velocity for each frame position
objectdistance = 0.002  # ukuran diameter pipa
imagedistance = 60  # 0.002 m = 60 pixel pada gambar
frame_rate = 4500  # Frame per detik
velocities = []

for pos_frame19, pos_frame20 in frame_positions:
    # Calculate displacement using the Euclidean distance formula
    displacement = ((pos_frame20[0] - pos_frame19[0]) ** 2 + (pos_frame20[1] - pos_frame19[1]) ** 2) ** 0.5
    
    # Convert displacement from pixel to real distance in meter
    real_distance_m = displacement * (objectdistance / imagedistance)
    
    # Calculate time between two frames (seconds)
    time_between_frames = 1 / frame_rate
    
    # Calculate velocity (meter per second)
    velocity = real_distance_m / time_between_frames

    # Tambahkan kecepatan ke dalam list
    velocities.append(velocity)
    
    print("Displacements :", displacement, "pixels")
    print("Velocity:", velocity, "m/s")
    print()

mean10 = sum(velocities) / len(velocities)

print("Velocity:", mean10, "m/s")
# Out:
# Displacements : 24.08318915758459 pixels
# Velocity: 3.6124783736376886 m/s
#
# Displacements : 30.066592756745816 pixels
# Velocity: 4.509988913511872 m/s
#
# Displacements : 25.179356624028344 pixels
# Velocity: 3.7769034936042516 m/s
#
# Displacements : 20.396078054371138 pixels
# Velocity: 3.059411708155671 m/s
#
# Displacements : 30.0 pixels
# Velocity: 4.5 m/s
#
# Displacements : 30.4138126514911 pixels
# Velocity: 4.562071897723665 m/s
#
# Velocity: 4.003475731105525 m/s

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Definisi posisi frame dan displacement
frame_positions = [
    ((103, 608), (101, 632)),
    ((101, 660), (103, 690)),
    ((106, 725), (103, 750)),
    ((114, 745), (110, 765)),
    ((200, 658), (200, 688)),
    ((215, 590), (210, 620)),
]

# Load the actual images
frame19 = cv2.imread('../Video/Frames0.75/frame0019.bmp', cv2.IMREAD_COLOR)
frame20 = cv2.imread('../Video/Frames0.75/frame0020.bmp', cv2.IMREAD_COLOR)

# Draw circles on the images at the bubble's positions
for pos_frame19, pos_frame20 in frame_positions:
    cv2.circle(frame19, pos_frame19, 10, (0, 255, 0), 2)  # Green circle for frame 0
    cv2.circle(frame20, pos_frame20, 10, (0, 255, 0), 2)  # Red circle for frame 1

# Convert images to RGB (Matplotlib expects RGB format)
frame19_rgb = cv2.cvtColor(frame19, cv2.COLOR_BGR2RGB)
frame20_rgb = cv2.cvtColor(frame20, cv2.COLOR_BGR2RGB)

# Display the images
plt.figure(figsize=(5, 10))
plt.subplot(1, 2, 1)
plt.imshow(frame19_rgb)
plt.title('Frame 19')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(frame20_rgb)
plt.title('Frame 20')
plt.axis('off')

plt.show()
cv2.imwrite('../video/pemilihan fitur/0.75/frame20_with_circles.jpg', frame20)
# Out:
# True
